# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_json('./covid.json')
df.head(18)
# Out:
#                                                                           ABW  \
# continent                                                       North America
# location                                                                Aruba
# population                                                             106766
# population_density                                                      584.8
# median_age                                                               41.2
# aged_65_older                                                          13.085
# aged_70_older                                                           7.452
# gdp_per_capita                                                        35973.8
# diabetes_prevalence                                                     11.62
# life_expectancy                                                         76.29
# data                        [{'date': '2020-03-13', 'total_cases': 2.0, 'n...
# ...

# %%
df.shape
# Out:
# (18, 211)

# %%
df.columns
# Out:
# Index(['ABW', 'AFG', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ATG',
#        ...
#        'VEN', 'VGB', 'VIR', 'VNM', 'OWID_KOS', 'YEM', 'ZAF', 'ZMB', 'ZWE',
#        'OWID_WRL'],
#       dtype='object', length=211)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, continent to male_smokers
# Columns: 211 entries, ABW to OWID_WRL
# dtypes: object(211)
# memory usage: 29.8+ KB

# %%
df.index
# Out:
# Index(['continent', 'location', 'population', 'population_density',
#        'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'diabetes_prevalence', 'life_expectancy', 'data',
#        'cardiovasc_death_rate', 'handwashing_facilities',
#        'hospital_beds_per_thousand', 'human_development_index',
#        'extreme_poverty', 'female_smokers', 'male_smokers'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   ABW                                                AFG  \
# count              11                                                 15
# unique             11                                                 15
# top     North America  [{'date': '2019-12-31', 'total_cases': 0.0, 'n...
# freq                1                                                  1
#
#                                                       AGO            AIA  \
# count                                                  14              5
# unique                                                 14              5
# top     [{'date': '2020-03-22', 'total_cases': 2.0, 'n...  North America
# freq                                                    1              1
#
#                                                       ALB  \
# count                                                  17
# unique                                                 17
# ...

# %%
df.head(18)
# Out:
#                                                                           ABW  \
# continent                                                       North America
# location                                                                Aruba
# population                                                             106766
# population_density                                                      584.8
# median_age                                                               41.2
# aged_65_older                                                          13.085
# aged_70_older                                                           7.452
# gdp_per_capita                                                        35973.8
# diabetes_prevalence                                                     11.62
# life_expectancy                                                         76.29
# data                        [{'date': '2020-03-13', 'total_cases': 2.0, 'n...
# ...

# %%
df.index
# Out:
# Index(['continent', 'location', 'population', 'population_density',
#        'median_age', 'aged_65_older', 'aged_70_older', 'gdp_per_capita',
#        'diabetes_prevalence', 'life_expectancy', 'data',
#        'cardiovasc_death_rate', 'handwashing_facilities',
#        'hospital_beds_per_thousand', 'human_development_index',
#        'extreme_poverty', 'female_smokers', 'male_smokers'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['ABW', 'AFG', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ATG',
#        ...
#        'VEN', 'VGB', 'VIR', 'VNM', 'OWID_KOS', 'YEM', 'ZAF', 'ZMB', 'ZWE',
#        'OWID_WRL'],
#       dtype='object', length=211)

# %%
df.loc['median_age', ['ABW', 'AFG', 'AGO', 'AIA']]
# Out:
# ABW    41.2
# AFG    18.6
# AGO    16.8
# AIA     NaN
# Name: median_age, dtype: object

# %%
df.loc['median_age']
# Out:
# ABW         41.2
# AFG         18.6
# AGO         16.8
# AIA          NaN
# ALB           38
#             ...
# YEM         20.3
# ZAF         27.3
# ZMB         17.7
# ZWE         19.6
# OWID_WRL    30.9
# Name: median_age, Length: 211, dtype: object

# %%
df.loc['data', 'AFG']
# Out:
# [{'date': '2019-12-31',
#   'total_cases': 0.0,
#   'new_cases': 0.0,
#   'total_deaths': 0.0,
#   'new_deaths': 0.0,
#   'total_cases_per_million': 0.0,
#   'new_cases_per_million': 0.0,
#   'total_deaths_per_million': 0.0,
#   'new_deaths_per_million': 0.0},
#  {'date': '2020-01-01',
#   'total_cases': 0.0,
#   'new_cases': 0.0,
#   'total_deaths': 0.0,
#   'new_deaths': 0.0,
#   'total_cases_per_million': 0.0,
#   'new_cases_per_million': 0.0,
#   'total_deaths_per_million': 0.0,
#   'new_deaths_per_million': 0.0,
#   'stringency_index': 0.0},
#  {'date': '2020-01-02',
#   'total_cases': 0.0,
#   'new_cases': 0.0,
#   'total_deaths': 0.0,
#   'new_deaths': 0.0,
#   'total_cases_per_million': 0.0,
#   'new_cases_per_million': 0.0,
#   'total_deaths_per_million': 0.0,
#   'new_deaths_per_million': 0.0,
#   'stringency_index': 0.0},
#  {'date': '2020-01-03',
#   'total_cases': 0.0,
#   'new_cases': 0.0,
#   'total_deaths': 0.0,
#   'new_deaths': 0.0,
# ...

# %%
dfAfg = pd.DataFrame(df.loc['data', 'ABW'])

# %%
dfAfg.head()
# Out:
#          date  total_cases  new_cases  total_deaths  new_deaths  \
# 0  2020-03-13          2.0        2.0           0.0         0.0
# 1  2020-03-19          NaN        NaN           NaN         NaN
# 2  2020-03-20          4.0        2.0           0.0         0.0
# 3  2020-03-21          NaN        NaN           NaN         NaN
# 4  2020-03-22          NaN        NaN           NaN         NaN
#
#    total_cases_per_million  new_cases_per_million  total_deaths_per_million  \
# 0                   18.733                 18.733                       0.0
# 1                      NaN                    NaN                       NaN
# 2                   37.465                 18.733                       0.0
# 3                      NaN                    NaN                       NaN
# 4                      NaN                    NaN                       NaN
#
#    new_deaths_per_million  stringency_index  new_cases_smoothed  \
# ...

# %%
df.iloc[0:9]
# Out:
#                                ABW          AFG          AGO            AIA  \
# continent            North America         Asia       Africa  North America
# location                     Aruba  Afghanistan       Angola       Anguilla
# population                  106766  3.89283e+07  3.28663e+07          15002
# population_density           584.8       54.422        23.89            NaN
# median_age                    41.2         18.6         16.8            NaN
# aged_65_older               13.085        2.581        2.405            NaN
# aged_70_older                7.452        1.337        1.362            NaN
# gdp_per_capita             35973.8      1803.99      5819.49            NaN
# diabetes_prevalence          11.62         9.59         3.94            NaN
#
#                             ALB      AND                   ARE            ARG  \
# continent                Europe   Europe                  Asia  South America
# ...

# %%
res = df.loc[['median_age', 'location']]

# %%
res.head()
# Out:
#               ABW          AFG     AGO       AIA      ALB      AND  \
# median_age   41.2         18.6    16.8       NaN       38      NaN
# location    Aruba  Afghanistan  Angola  Anguilla  Albania  Andorra
#
#                              ARE        ARG      ARM                  ATG  \
# median_age                    34       31.9     35.7                 32.1
# location    United Arab Emirates  Argentina  Armenia  Antigua and Barbuda
#
#             ...        VEN                     VGB  \
# median_age  ...         29                     NaN
# location    ...  Venezuela  British Virgin Islands
#
#                                      VIR      VNM OWID_KOS    YEM  \
# median_age                          42.2     32.6      NaN   20.3
# location    United States Virgin Islands  Vietnam   Kosovo  Yemen
#
#                      ZAF     ZMB       ZWE OWID_WRL
# median_age          27.3    17.7      19.6     30.9
# location    South Africa  Zambia  Zimbabwe    World
#
# ...

# %%
res.index
# Out:
# Index(['median_age', 'location'], dtype='object')

# %%
res.columns
# Out:
# Index(['ABW', 'AFG', 'AGO', 'AIA', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ATG',
#        ...
#        'VEN', 'VGB', 'VIR', 'VNM', 'OWID_KOS', 'YEM', 'ZAF', 'ZMB', 'ZWE',
#        'OWID_WRL'],
#       dtype='object', length=211)

# %%
newDf = pd.DataFrame({'country': df.loc['location'], 'median_age': df.loc['median_age']})

# %%
newDf.head(25)
# Out:
#                              country median_age
# ABW                            Aruba       41.2
# AFG                      Afghanistan       18.6
# AGO                           Angola       16.8
# AIA                         Anguilla        NaN
# ALB                          Albania         38
# AND                          Andorra        NaN
# ARE             United Arab Emirates         34
# ARG                        Argentina       31.9
# ARM                          Armenia       35.7
# ATG              Antigua and Barbuda       32.1
# AUS                        Australia       37.9
# AUT                          Austria       44.4
# AZE                       Azerbaijan       32.4
# BDI                          Burundi       17.5
# BEL                          Belgium       41.8
# BEN                            Benin       18.8
# BES  Bonaire Sint Eustatius and Saba        NaN
# BFA                     Burkina Faso       17.6
# BGD                       Bangladesh       27.5
# ...

# %%
withoutAge=newDf.loc[newDf['median_age'].isnull(), :]
withoutAge.shape
# Out:
# (24, 2)

# %%
withoutAge
# Out:
#                                   country median_age
# AIA                              Anguilla        NaN
# AND                               Andorra        NaN
# BES       Bonaire Sint Eustatius and Saba        NaN
# BMU                               Bermuda        NaN
# CYM                        Cayman Islands        NaN
# DMA                              Dominica        NaN
# FLK                      Falkland Islands        NaN
# FRO                        Faeroe Islands        NaN
# GGY                              Guernsey        NaN
# GIB                             Gibraltar        NaN
# GRL                             Greenland        NaN
# IMN                           Isle of Man        NaN
# JEY                                Jersey        NaN
# KNA                 Saint Kitts and Nevis        NaN
# LIE                         Liechtenstein        NaN
# MCO                                Monaco        NaN
# MNP              Northern Mariana Islands        NaN
# ...

# %%
withAge = newDf.loc[newDf['median_age'].notnull(), :]

# %%
withAge.shape
# Out:
# (187, 2)

# %%
medianaAge=withAge['median_age'].mean()
int(medianaAge)
# Out:
# 30

# %%
newDf['median_age']=pd.DataFrame(newDf['median_age']).fillna(int(medianaAge))

# %%
withAge = newDf.loc[newDf['median_age'].notnull(), :]

# %%
withAge.shape
# Out:
# (211, 2)

# %%
withAge.head(25)
# Out:
#                              country  median_age
# ABW                            Aruba        41.2
# AFG                      Afghanistan        18.6
# AGO                           Angola        16.8
# AIA                         Anguilla        30.0
# ALB                          Albania        38.0
# AND                          Andorra        30.0
# ARE             United Arab Emirates        34.0
# ARG                        Argentina        31.9
# ARM                          Armenia        35.7
# ATG              Antigua and Barbuda        32.1
# AUS                        Australia        37.9
# AUT                          Austria        44.4
# AZE                       Azerbaijan        32.4
# BDI                          Burundi        17.5
# BEL                          Belgium        41.8
# BEN                            Benin        18.8
# BES  Bonaire Sint Eustatius and Saba        30.0
# BFA                     Burkina Faso        17.6
# ...

# %%
withAge['median_age'].max()
# Out:
# 48.2

# %%
withAge['median_age'].idxmax()
# Out:
# 'JPN'

# %%
withAge.loc['JPN']
# Out:
# country       Japan
# median_age     48.2
# Name: JPN, dtype: object

# %%
withAge.loc['JPN'].country
# Out:
# 'Japan'

# %%
withAge['median_age']
# Out:
# ABW         41.2
# AFG         18.6
# AGO         16.8
# AIA         30.0
# ALB         38.0
#             ...
# YEM         20.3
# ZAF         27.3
# ZMB         17.7
# ZWE         19.6
# OWID_WRL    30.9
# Name: median_age, Length: 211, dtype: float64

# %%
plt.hist(withAge['median_age'], bins = 50)
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(withAge['median_age'], orient='v')
plt.show()
